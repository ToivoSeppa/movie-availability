# %%
pip install requests

# %%
import requests
import json
import pandas as pd

movie_id_list = []
movie_name_list = []
vote_average_list = []

for i in range(39):
  url = f"https://api.themoviedb.org/3/account/20974523/watchlist/movies?language=en-US&page={i+1}&sort_by=created_at.asc"

  headers = {
      "accept": "application/json",
      "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NGMyM2UzMTRiNTdhYjQwNTk1YzFmYzQ5YmVlMGI4YSIsIm5iZiI6MTcwNzMzNjY4OC43ODQsInN1YiI6IjY1YzNlM2YwMmI4YTQzMDE0NzM5ZGQ0YyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Lb4qZm8bCyOU_v2Xe2lXl0EQg34KEZdDMSrZxyR0ges"
  }

  response = requests.get(url, headers=headers)

  data = response.json()

  # Extract `id` and `original_title`
  for result in data['results']:
      movie_id = result['id']
      original_title = result['original_title']
      vote_average = result['vote_average']
      movie_id_list.append(movie_id)
      movie_name_list.append(original_title)
      vote_average_list.append(vote_average)

# %%
dict = {'movieId': movie_id_list, 'movieName': movie_name_list, 'voteAverage': vote_average_list}

df = pd.DataFrame(dict)

print(df)
# Out:
#      movieId                   movieName  voteAverage
# 0      76341          Mad Max: Fury Road        7.618
# 1        525          The Blues Brothers        7.731
# 2       2604  Born on the Fourth of July        7.000
# 3      64690                       Drive        7.581
# 4        948                   Halloween        7.563
# ..       ...                         ...          ...
# 775      242      The Godfather Part III        7.421
# 776   551332               The Two Popes        7.494
# 777    87502                      Flight        6.843
# 778      765                Evil Dead II        7.546
# 779    22881              The Blind Side        7.672
#
# [780 rows x 3 columns]

# %%
providers_fin = []
for movie in df['movieId']:

  url = f"https://api.themoviedb.org/3/movie/{movie}/watch/providers"

  headers = {
      "accept": "application/json",
      "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NGMyM2UzMTRiNTdhYjQwNTk1YzFmYzQ5YmVlMGI4YSIsIm5iZiI6MTcwNzMzNjY4OC43ODQsInN1YiI6IjY1YzNlM2YwMmI4YTQzMDE0NzM5ZGQ0YyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Lb4qZm8bCyOU_v2Xe2lXl0EQg34KEZdDMSrZxyR0ges"
  }

  response = requests.get(url, headers=headers)

  data = response.json()
  # Extract flatrate provider names in Finland
  finland_data = data.get("results", {}).get("FI", {}).get("flatrate", [])
  provider_names = [provider["provider_name"] for provider in finland_data]

  providers_fin.append(provider_names)

# %%
df.insert(3, "providersFin", providers_fin)

# %%
df
# Out:
#      movieId                   movieName  voteAverage          providersFin
# 0      76341          Mad Max: Fury Road        7.618        [Netflix, Max]
# 1        525          The Blues Brothers        7.731  [Amazon Prime Video]
# 2       2604  Born on the Fourth of July        7.000  [Ruutu, SkyShowtime]
# 3      64690                       Drive        7.581        [Viaplay, Max]
# 4        948                   Halloween        7.563             [Cultpix]
# ..       ...                         ...          ...                   ...
# 775      242      The Godfather Part III        7.421  [Ruutu, SkyShowtime]
# 776   551332               The Two Popes        7.494             [Netflix]
# 777    87502                      Flight        6.843         [SkyShowtime]
# 778      765                Evil Dead II        7.546                    []
# 779    22881              The Blind Side        7.672                    []
#
# [780 rows x 4 columns]

# %%
df.sort_values(by=['voteAverage'], ascending=False)
# Out:
#      movieId                               movieName  voteAverage  \
# 705      424                        Schindler's List        8.600
# 696       13                            Forrest Gump        8.500
# 6        389                            12 Angry Men        8.500
# 54     12477                                   火垂るの墓        8.500
# 707   372058                                   君の名は。        8.485
# ..       ...                                     ...          ...
# 262  1035088                        Поговори со мной        0.000
# 578   696506                               Mickey 17        0.000
# 580  1054867              The Battle of Baktan Cross        0.000
# 587   541671  From the World of John Wick: Ballerina        0.000
# 389   911916     Spider-Man: Beyond the Spider-Verse        0.000
#
#              providersFin
# 705               [Ruutu]
# 696         [SkyShowtime]
# 6    [MGM Amazon Channel]
# 54              [Netflix]
# 707                    []
# ...
